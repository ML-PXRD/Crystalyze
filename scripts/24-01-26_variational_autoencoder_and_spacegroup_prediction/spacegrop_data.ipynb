# %%
import pandas as pd 
import numpy as np
import torch

# %%
data_dir = '/home/gridsan/tmackey/cdvae/data/mp_20_final/'
train_df = pd.read_csv(data_dir+'train.csv')

# %%
train_df['spacegroup.number']
# Out:
# 0          8
# 1        139
# 2        225
# 3         62
# 4        122
#         ...
# 27131    155
# 27132    225
# 27133     64
# 27134    191
# 27135     63
# Name: spacegroup.number, Length: 27136, dtype: int64

# %%
train_df
# Out:
#        Unnamed: 0 material_id  formation_energy_per_atom  band_gap  \
# 0           37228  mp-1221227                  -1.637460    0.2133
# 1           19480   mp-974729                  -0.314759    0.0000
# 2           29624  mp-1185360                  -0.193761    0.0000
# 3           38633  mp-1188861                  -0.584694    3.8556
# 4           10889   mp-677272                  -2.474759    0.4707
# ...           ...         ...                        ...       ...
# 27131       37856   mp-568116                  -0.988502    3.7614
# 27132       11955   mp-865529                  -0.640955    0.0000
# 27133       26119  mp-1189241                  -0.756019    0.0000
# 27134       30556  mp-1104538                  -0.104870    0.0000
# 27135       32933   mp-756354                  -3.712252    2.7684
#
#       pretty_formula  e_above_hull                       elements  \
# 0        Na3MnCoNiO6      0.043001  ['Co', 'Mn', 'Na', 'Ni', 'O']
# ...
