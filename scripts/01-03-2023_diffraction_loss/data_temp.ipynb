# %%
import numpy as np
import pandas as pd
import torch

# %%
test_data = pd.read_csv('/home/gridsan/groups/Freedman_CDVAE/XRD_CDVAE_Repo/data/mp_20/test.csv')

# %%
test_data
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 material_id  \
# 0                0             0          65   mp-865981
# 1                1             1       32049  mp-1103778
# 2                2             2       27350    mp-39712
# 3                3             3       26417   mp-754553
# 4                4             4        9763    mp-20332
# ...            ...           ...         ...         ...
# 9042          9042          9042       21009  mp-1023925
# 9043          9043          9043       31626  mp-1187764
# 9044          9044          9044       20673  mp-1219588
# 9045          9045          9045        5349     mp-3589
# 9046          9046          9046       34318  mp-1518304
#
#       formation_energy_per_atom  band_gap pretty_formula  e_above_hull  \
# 0                     -0.436368    0.0000        TmMgHg2      0.000000
# 1                     -2.755559    3.5845        HoWClO4      0.025353
# ...

# %%
pt_file_path = '/home/gridsan/groups/Freedman_CDVAE/XRD_CDVAE_Repo/data/mp_20/test.pt'
graph_dict = torch.load(pt_file_path)
some = graph_dict['mp-864962'][2]
print(some)
torch.Tensor(some).view(1,-1)
# Out:
# [5.40383306 5.40383306 5.40383306]
# tensor([[5.4038, 5.4038, 5.4038]])
